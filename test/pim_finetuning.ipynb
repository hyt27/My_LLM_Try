# %%
import sys
import logging

# %%
import datasets
from datasets import load_dataset
from peft import LoraConfig
import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, BitsAndBytesConfig

# %%
# !pip install trl
# Out:
# Collecting trl
#   Downloading trl-0.9.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.4.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from trl) (2.0.0+nv23.5)
# Requirement already satisfied: transformers>=4.31.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from trl) (4.37.2)
# Requirement already satisfied: numpy>=1.18.2 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from trl) (1.24.4)
# Requirement already satisfied: accelerate in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from trl) (0.31.0)
# Requirement already satisfied: datasets in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from trl) (2.20.0)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.8.4-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: filelock in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from torch>=1.4.0->trl) (3.14.0)
# Requirement already satisfied: jinja2 in /home/chcheadmin/.local/lib/python3.8/site-packages (from torch>=1.4.0->trl) (3.1.4)
# Requirement already satisfied: networkx in /home/chcheadmin/.local/lib/python3.8/site-packages (from torch>=1.4.0->trl) (3.1)
# Requirement already satisfied: sympy in /home/chcheadmin/.local/lib/python3.8/site-packages (from torch>=1.4.0->trl) (1.12.1)
# Requirement already satisfied: typing-extensions in /home/chcheadmin/.local/lib/python3.8/site-packages (from torch>=1.4.0->trl) (4.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (0.23.3)
# Requirement already satisfied: packaging>=20.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (2024.5.15)
# Requirement already satisfied: requests in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (2.28.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from transformers>=4.31.0->trl) (4.65.2)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: rich>=11.1.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from tyro>=0.5.11->trl) (13.4.2)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting eval-type-backport>=0.1.3 (from tyro>=0.5.11->trl)
#   Downloading eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: psutil in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from accelerate->trl) (5.9.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from datasets->trl) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from datasets->trl) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from datasets->trl) (0.3.8)
# Requirement already satisfied: pandas in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from datasets->trl) (2.0.3)
# Collecting requests (from transformers>=4.31.0->trl)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.27 (from transformers>=4.31.0->trl)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: xxhash in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: multiprocess in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from datasets->trl) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets->trl) (2024.5.0)
# Requirement already satisfied: aiohttp in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from datasets->trl) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from aiohttp->datasets->trl) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from aiohttp->datasets->trl) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from requests->transformers>=4.31.0->trl) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from requests->transformers>=4.31.0->trl) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from requests->transformers>=4.31.0->trl) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from requests->transformers>=4.31.0->trl) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/chcheadmin/.local/lib/python3.8/site-packages (from jinja2->torch>=1.4.0->trl) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from pandas->datasets->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from pandas->datasets->trl) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from pandas->datasets->trl) (2024.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/chcheadmin/.local/lib/python3.8/site-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/chcheadmin/anaconda3/envs/py38/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Downloading trl-0.9.4-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 8.3 MB/s eta 0:00:00
# Downloading tyro-0.8.4-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 5.5 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, shtab, requests, eval-type-backport, docstring-parser, tyro, trl
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.2
#     Uninstalling tqdm-4.65.2:
#       Successfully uninstalled tqdm-4.65.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.2
#     Uninstalling requests-2.28.2:
#       Successfully uninstalled requests-2.28.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openxlab 0.1.0 requires requests~=2.28.2, but you have requests 2.32.3 which is incompatible.
# openxlab 0.1.0 requires setuptools~=60.2.0, but you have setuptools 70.1.0 which is incompatible.
# openxlab 0.1.0 requires tqdm~=4.65.0, but you have tqdm 4.66.4 which is incompatible.
# Successfully installed docstring-parser-0.16 eval-type-backport-0.2.0 requests-2.32.3 shtab-1.7.1 tqdm-4.66.4 trl-0.9.4 tyro-0.8.4

# %%
from trl import SFTTrainer
# Out:
# [2024-06-25 15:48:47,141] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /home/chcheadmin/anaconda3/envs/py38/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  please install triton==1.0.0 if you want to use sparse attention

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# accelerate                    0.31.0
# aiofiles                      23.2.1
# aiohttp                       3.9.5
# aiosignal                     1.3.1
# aliyun-python-sdk-core        2.15.1
# aliyun-python-sdk-kms         2.16.3
# altair                        5.3.0
# annotated-types               0.7.0
# anyio                         4.2.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# async-lru                     2.0.4
# async-timeout                 4.0.3
# attrs                         23.1.0
# Babel                         2.11.0
# backcall                      0.2.0
# beautifulsoup4                4.12.3
# bitsandbytes                  0.42.0
# bleach                        4.1.0
# brotlipy                      0.7.0
# certifi                       2024.6.2
# cffi                          1.16.0
# charset-normalizer            2.0.4
# click                         8.1.7
# colorama                      0.4.6
# comm                          0.2.1
# contourpy                     1.1.1
# cpm-kernels                   1.0.11
# crcmod                        1.7
# cryptography                  42.0.5
# cycler                        0.12.1
# datasets                      2.20.0
# debugpy                       1.6.7
# decorator                     5.1.1
# deepspeed                     0.14.4
# defusedxml                    0.7.1
# dill                          0.3.8
# dnspython                     2.6.1
# docstring_parser              0.16
# einops                        0.8.0
# email_validator               2.1.1
# eval_type_backport            0.2.0
# exceptiongroup                1.2.0
# executing                     0.8.3
# fastapi                       0.111.0
# fastapi-cli                   0.0.4
# fastjsonschema                2.16.2
# ffmpy                         0.3.2
# filelock                      3.14.0
# fonttools                     4.53.0
# frozenlist                    1.4.1
# fsspec                        2024.5.0
# gradio                        4.36.1
# gradio_client                 1.0.1
# h11                           0.14.0
# hjson                         3.1.0
# httpcore                      1.0.5
# httptools                     0.6.1
# httpx                         0.27.0
# huggingface-hub               0.23.3
# idna                          3.7
# importlib-metadata            7.0.1
# importlib-resources           6.1.1
# ipykernel                     6.28.0
# ipython                       8.12.2
# ipywidgets                    8.1.2
# jedi                          0.18.1
# jieba                         0.42.1
# Jinja2                        3.1.4
# jmespath                      0.10.0
# joblib                        1.4.2
# json5                         0.9.6
# jsonschema                    4.19.2
# jsonschema-specifications     2023.7.1
# jupyter                       1.0.0
# jupyter_client                8.6.0
# jupyter-console               6.6.3
# jupyter_core                  5.5.0
# jupyter-events                0.8.0
# jupyter-lsp                   2.2.0
# jupyter_server                2.10.0
# jupyter_server_terminals      0.4.4
# jupyterlab                    4.0.11
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.25.1
# jupyterlab-widgets            3.0.10
# kiwisolver                    1.4.5
# latex2mathml                  3.77.0
# Markdown                      3.6
# markdown-it-py                3.0.0
# MarkupSafe                    2.1.5
# matplotlib                    3.7.5
# matplotlib-inline             0.1.6
# mdtex2html                    1.3.0
# mdurl                         0.1.2
# mistune                       2.0.4
# model-index                   0.1.11
# mpmath                        1.3.0
# multidict                     6.0.5
# multiprocess                  0.70.16
# nbclient                      0.8.0
# nbconvert                     7.10.0
# nbformat                      5.9.2
# nest-asyncio                  1.6.0
# networkx                      3.1
# ninja                         1.11.1.1
# nltk                          3.8.1
# notebook                      7.0.8
# notebook_shim                 0.2.3
# numpy                         1.24.4
# nvidia-ml-py                  12.555.43
# opendatalab                   0.0.10
# openmim                       0.3.9
# openxlab                      0.1.0
# ordered-set                   4.1.0
# orjson                        3.10.4
# oss2                          2.17.0
# overrides                     7.4.0
# packaging                     24.1
# pandas                        2.0.3
# pandocfilters                 1.5.0
# parso                         0.8.3
# peft                          0.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# pillow                        10.3.0
# pip                           24.1
# pkgutil_resolve_name          1.3.10
# platformdirs                  3.10.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.43
# protobuf                      5.27.1
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyarrow                       16.1.0
# pyarrow-hotfix                0.6
# pycparser                     2.21
# pycryptodome                  3.20.0
# pydantic                      2.7.4
# pydantic_core                 2.18.4
# pydub                         0.25.1
# Pygments                      2.15.1
# pyOpenSSL                     24.0.0
# pyparsing                     3.1.2
# PySocks                       1.7.1
# python-dateutil               2.9.0.post0
# python-dotenv                 1.0.1
# python-json-logger            2.0.7
# python-multipart              0.0.9
# pytz                          2023.4
# PyYAML                        6.0.1
# pyzmq                         25.1.2
# referencing                   0.30.2
# regex                         2024.5.15
# requests                      2.32.3
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rich                          13.4.2
# rouge-chinese                 1.0.3
# rpds-py                       0.10.6
# ruff                          0.4.8
# safetensors                   0.4.3
# scipy                         1.10.1
# semantic-version              2.10.0
# Send2Trash                    1.8.2
# sentencepiece                 0.2.0
# setuptools                    70.1.0
# shellingham                   1.5.4
# shtab                         1.7.1
# six                           1.16.0
# sniffio                       1.3.0
# soupsieve                     2.5
# stack-data                    0.2.0
# starlette                     0.37.2
# sympy                         1.12.1
# tabulate                      0.9.0
# terminado                     0.17.1
# tiktoken                      0.7.0
# tinycss2                      1.2.1
# tokenizers                    0.15.2
# tomli                         2.0.1
# tomlkit                       0.12.0
# toolz                         0.12.1
# torch                         1.11.0
# tornado                       6.3.3
# tqdm                          4.66.4
# traitlets                     5.14.3
# transformers                  4.37.2
# transformers-stream-generator 0.0.4
# trl                           0.9.4
# typer                         0.12.3
# typing_extensions             4.12.2
# tyro                          0.8.4
# tzdata                        2024.1
# ujson                         5.10.0
# urllib3                       1.26.18
# uvicorn                       0.30.1
# uvloop                        0.19.0
# watchfiles                    0.22.0
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.8.0
# websockets                    11.0.3
# wheel                         0.43.0
# widgetsnbextension            4.0.10
# xxhash                        3.4.1
# yarl                          1.9.4
# zipp                          3.17.0

# %%
logger = logging.getLogger(__name__)

# %%
###################
# Hyper-parameters
###################
training_config = {
    "bf16": True,
    "do_eval": False,
    "learning_rate": 5.0e-06,
    "log_level": "info",
    "logging_steps": 20,
    "logging_strategy": "steps",
    "lr_scheduler_type": "cosine",
    "num_train_epochs": 1,
    "max_steps": -1,
    "output_dir": "./checkpoint_dir",
    "overwrite_output_dir": True,
    "per_device_eval_batch_size": 4,
    "per_device_train_batch_size": 4,
    "remove_unused_columns": True,
    "save_steps": 100,
    "save_total_limit": 1,
    "seed": 0,
    "gradient_checkpointing": True,
    "gradient_checkpointing_kwargs":{"use_reentrant": False},
    "gradient_accumulation_steps": 1,
    "warmup_ratio": 0.2,
    }

peft_config = {
    "r": 16,
    "lora_alpha": 32,
    "lora_dropout": 0.05,
    "bias": "none",
    "task_type": "CAUSAL_LM",
    "target_modules": "all-linear",
    "modules_to_save": None,
}
train_conf = TrainingArguments(**training_config)
peft_conf = LoraConfig(**peft_config)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 37
#       4 training_config = {
#       5     "bf16": True,
#       6     "do_eval": False,
#    (...)
#      25     "warmup_ratio": 0.2,
#      26     }
#      28 peft_config = {
#      29     "r": 16,
#      30     "lora_alpha": 32,
#    (...)
#      35     "modules_to_save": None,
#      36 }
# ---> 37 train_conf = TrainingArguments(**training_config)
#      38 peft_conf = LoraConfig(**peft_config)
#
# File <string>:121, in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, evaluation_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, lr_scheduler_kwargs, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, ddp_broadcast_buffers, dataloader_pin_memory, dataloader_persistent_workers, skip_memory_metrics, use_legacy_prediction_loop, push_to_hub, resume_from_checkpoint, hub_model_id, hub_strategy, hub_token, hub_private_repo, hub_always_push, gradient_checkpointing, gradient_checkpointing_kwargs, include_inputs_for_metrics, fp16_backend, push_to_hub_model_id, push_to_hub_organization, push_to_hub_token, mp_parameters, auto_find_batch_size, full_determinism, torchdynamo, ray_scope, ddp_timeout, torch_compile, torch_compile_backend, torch_compile_mode, dispatch_batches, split_batches, include_tokens_per_second, include_num_input_tokens_seen, neftune_noise_alpha)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/transformers/training_args.py:1445, in TrainingArguments.__post_init__(self)
#    1442                 from .pytorch_utils import is_torch_greater_or_equal_than_1_12
#    1444                 if not is_torch_greater_or_equal_than_1_12:
# -> 1445                     raise ValueError(
#    1446                         "Your setup doesn't support bf16/xpu. You need torch>=1.12, using Intel XPU/GPU with IPEX installed"
#    1447                     )
#    1449 if self.fp16 and self.bf16:
#    1450     raise ValueError("At most one of fp16 and bf16 can be True, but not both")
#
# ValueError: Your setup doesn't support bf16/xpu. You need torch>=1.12, using Intel XPU/GPU with IPEX installed
